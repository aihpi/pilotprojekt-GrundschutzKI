# %% [markdown]
# # 05_json_preprocessing
#
# Dieses Notebook lädt `grundschutz.json`, erzeugt kompakte Retrieval-Dokumente und speichert optional JSONL/Parquet.

# %%
import json
from pathlib import Path
import pandas as pd

# %%
# Pfad zur JSON
data_path = Path('../data/data_preprocessed/grundschutz.json')
data = json.loads(data_path.read_text())
data.keys()

# %%
# Struktur-Check
len(data.get('schichten', [])), data.get('schichten', [])[0].keys()

# %%
def build_retrieval_docs(gs):
    docs = []
    for schicht in gs.get('schichten', []):
        schicht_name = schicht.get('name')
        schicht_typ = schicht.get('typ')
        for b in schicht.get('bausteine', []):
            baustein_id = b.get('id')
            baustein_titel = b.get('titel')
            beschreibung = (b.get('beschreibung') or {}).get('text', '')
            gefaehrdungslage = (b.get('gefaehrdungslage') or {}).get('text', '')

            anforderungen = b.get('anforderungen') or {}
            for level, reqs in anforderungen.items():
                for req in reqs:
                    text = req.get('inhalt', '')
                    if not text:
                        continue
                    docs.append({
                        'id': req.get('id'),
                        'text': text,
                        'meta': {
                            'schicht': schicht_name,
                            'schicht_typ': schicht_typ,
                            'baustein_id': baustein_id,
                            'baustein_titel': baustein_titel,
                            'level': level,  # basis/standard/erhoeht
                            'typ': req.get('typ'),
                            'modal_verben': req.get('modal_verben', []),
                            'beschreibung': beschreibung,
                            'gefaehrdungslage': gefaehrdungslage,
                        }
                    })
    return docs

# %%
docs = build_retrieval_docs(data)
len(docs)

# %%
df = pd.DataFrame(docs)
df.head()

# %%
from pathlib import Path
import sys

# Make notebooks/ importable when running from Jupyter
NOTEBOOK_DIR = Path.cwd()
if (NOTEBOOK_DIR / "litellm_client.py").exists():
    sys.path.insert(0, str(NOTEBOOK_DIR))
elif (NOTEBOOK_DIR / "notebooks" / "litellm_client.py").exists():
    sys.path.insert(0, str(NOTEBOOK_DIR / "notebooks"))

from litellm_client import (
    chat_completion,
    get_embeddings,
    get_qdrant_client,
    load_llm_config,
    load_vectordb_config,
)
# Qdrant-Verbindung prüfen
from qdrant_client.http import models as qmodels

llm_cfg = load_llm_config()
vec_cfg = load_vectordb_config()
client = get_qdrant_client(vec_cfg)

collection_name = "grundschutz_json"
# Out:
# /Users/felixboelter/Documents/GitHub/pilotprojekt-GrundschutzKI/notebooks/litellm_client.py:177: UserWarning: Api key is used with an insecure connection.
#   return QdrantClient(url=url, api_key=cfg.api_key)

# %%
# chunks aus df (eine Zeile = ein Chunk)
chunks = df["text"].tolist()
metas = df["meta"].tolist()

embeddings = get_embeddings(chunks, llm_cfg, batch_size=256)
vector_size = len(embeddings[0])

client.recreate_collection(
    collection_name=collection_name,
    vectors_config=qmodels.VectorParams(size=vector_size, distance=qmodels.Distance.COSINE),
)

points = []
for idx, (text, vector, meta) in enumerate(zip(chunks, embeddings, metas)):
    points.append(
        qmodels.PointStruct(
            id=idx,
            vector=vector,
            payload={"text": text, **meta},
        )
    )

BATCH_SIZE = 128
for start in range(0, len(points), BATCH_SIZE):
    client.upsert(collection_name=collection_name, points=points[start:start+BATCH_SIZE])

# %% [markdown]
# # INFERENCE

# %%
from datasets import Dataset
import pandas as pd

def _retrieve_contexts(question: str, k: int, client, collection_name: str, llm_cfg):
    query_emb = get_embeddings([question], llm_cfg, batch_size=1)[0]
    results = client.query_points(
        collection_name=collection_name,
        query=query_emb,
        limit=k,
    ).points
    return [res.payload.get('text', '') for res in results]

def build_eval_dataset(
    csv_path: str = '../data/data_evaluation/GSKI_Fragen-Antworten-Fundstellen.csv',
    top_k: int = 5,
) -> Dataset:
    llm_cfg = load_llm_config()
    vec_cfg = load_vectordb_config()
    qdrant_client = get_qdrant_client(vec_cfg)
    collection_name = vec_cfg.collection or 'grundschutz_xml'

    df = pd.read_csv(Path(csv_path), sep=';', encoding='utf-8-sig')
    records = []

    for _, row in df.iterrows():
        question = row['Frage']
        ground_truth_answer = row['Antwort']
        ground_truth_context = row['Fundstellen im IT-Grundschutz-Kompendium 2023']

        contexts = _retrieve_contexts(question, top_k, qdrant_client, collection_name, llm_cfg)

        records.append({
            'question': question,
            'contexts': contexts,
            'ground_truth_answer': ground_truth_answer,
            'ground_truth_context': ground_truth_context,
        })

    return Dataset.from_list(records)

dataset = build_eval_dataset(top_k=6)
dataset
# Out:
# /Users/felixboelter/Documents/GitHub/pilotprojekt-GrundschutzKI/notebooks/litellm_client.py:177: UserWarning: Api key is used with an insecure connection.
#   return QdrantClient(url=url, api_key=cfg.api_key)
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Processing embeddings 0 to 1 / 1
# Dataset({
#     features: ['question', 'contexts', 'ground_truth_answer', 'ground_truth_context'],
#     num_rows: 42
# })

# %%
import json
import dspy
def docs_to_context(docs):
    # docs can be list of strings OR list of dicts
    doc_list = []
    for i, d in enumerate(docs):
        text = d["text"] if isinstance(d, dict) else d
        doc_list.append({"doc_id": i+1, "title": "", "text": text, "source": ""})
    return "<documents>\n" + json.dumps(doc_list, ensure_ascii=False, indent=2) + "\n</documents>"


class RAGAnswerJSON(dspy.Signature):
    """Antworte auf Deutsch, kurz und präzise, max. 2–3 Sätze.
    Nutze ausschließlich den Kontext in <documents>...</documents>.
    Wenn die Antwort nicht im Kontext steht, sage das."""
    question: str = dspy.InputField()
    context: str = dspy.InputField()
    response: str = dspy.OutputField(desc='Antwort auf Deutsch, kurz und präzise, maximal 2–3 Sätze.')

class RAGModuleJSON(dspy.Module):
    def __init__(self):
        super().__init__()
        self.predict = dspy.Predict(RAGAnswerJSON)

    def forward(self, question, docs):
        context = docs_to_context(docs)
        return self.predict(question=question, context=context)

rag_json = RAGModuleJSON()

# %%
import dspy
from litellm_client import load_llm_config

llm_cfg = load_llm_config()
model = "openai/gpt-oss-120b"
# model = "openai/granite-4-h-tiny"

# LiteLLM‑Proxy (OpenAI‑kompatibel)
dspy_llm = dspy.LM(
    model=model,
    api_base=llm_cfg.api_base,
    api_key=llm_cfg.api_key,
)

dspy.configure(lm=dspy_llm)

# %%
import dspy
from dspy.evaluate import SemanticF1

# DSPy Examples aus dem vorhandenen Dataset
examples = []
for row in dataset:
    examples.append(
        dspy.Example(
            question=row["question"],
            docs=row["contexts"],
            response=row["ground_truth_answer"],  # <-- richtiges Feld
        ).with_inputs("question", "docs")
    )


# einfache Splits
trainset = examples[: max(1, len(examples)//5)]
devset = examples[max(1, len(examples)//5):]

metric = SemanticF1(decompositional=True)

# Optimizer (wenig Threads zum Start)
tp = dspy.MIPROv2(metric=metric, auto='light', num_threads=6)
optimized_rag = tp.compile(rag_json, trainset=trainset)
# Out:
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2:
# RUNNING WITH THE FOLLOWING LIGHT AUTO RUN SETTINGS:
# num_trials: 10
# minibatch: False
# num_fewshot_candidates: 6
# num_instruct_candidates: 3
# valset size: 6
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 1: BOOTSTRAP FEWSHOT EXAMPLES <==
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: These will be used as few-shot example candidates for our program and for creating instructions.
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: Bootstrapping N=6 sets of demonstrations...
# Bootstrapping set 1/6
# Bootstrapping set 2/6
# Bootstrapping set 3/6
# 100%|██████████| 2/2 [00:00<00:00, 14.11it/s]
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 2 attempts.
# Bootstrapping set 4/6
# 100%|██████████| 2/2 [00:00<00:00, 17.12it/s]
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 2 attempts.
# Bootstrapping set 5/6
#  50%|█████     | 1/2 [00:00<00:00, 17.88it/s]
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 1 attempts.
# Bootstrapping set 6/6
#  50%|█████     | 1/2 [00:00<00:00, 17.30it/s]
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 2: PROPOSE INSTRUCTION CANDIDATES <==
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: We will use the few-shot examples from the previous step, a generated dataset summary, a summary of the program code, and a randomly selected prompting tip to propose instructions.
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2:
# Proposing N=3 instructions...
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 1 attempts.
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: Proposed Instructions for Predictor 0:
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: 0: Antworte auf Deutsch, kurz und präzise, max. 2–3 Sätze.
# Nutze ausschließlich den Kontext in <documents>...</documents>.
# Wenn die Antwort nicht im Kontext steht, sage das.
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: 1: Antworte auf Deutsch in maximal 2–3 Sätzen. Verwende ausschließlich den Text, der zwischen den `<documents>…</documents>`‑Tags steht.
#
# - Zitiere den relevanten Abschnitt **exakt** (inkl. der Wörter „MUSS“ oder „SOLLTE“, falls vorhanden) und **nenne die zugehörige Baustein‑Kennung** (z. B. APP.2.1, SYS.3.2.1).
# - Wenn mehrere passende Passagen existieren, führe nur die **erste** passende Passage an.
# - Sollte die benötigte Information im Kontext nicht vorhanden sein, antworte wörtlich: **„Die Information ist nicht im Kontext enthalten.“**
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: 2: Antworte auf Deutsch in **maximal 2 – 3 Sätzen** und verwende **ausschließlich** den Text, der sich innerhalb der Tags `<documents> … </documents>` befindet.
# - **Zitiere exakt** die Passagen, die mit **„MUSS“** (verbindlich) oder **„SOLLTE“** (empfohlen) gekennzeichnet sind, und **füge den zugehörigen Baustein‑Code** (z. B. APP.2.1, INF.14, ORP.1) unmittelbar hinter dem Zitat ein.
# - Formuliere die Antwort **formal und präzise**, ohne eigene Ergänzungen oder Interpretation.
# - **Wenn die geforderte Information im Kontext nicht vorkommt**, antworte schlicht: **„Keine Information im Kontext.“**
#
# Stelle sicher, dass das Ergebnis ein kurzer, faktengestützter Satz ist, der die geforderte Anforderung und den entsprechenden Modulcode enthält.
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2:
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: ==> STEP 3: FINDING OPTIMAL PROMPT PARAMETERS <==
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: We will evaluate the program over a series of trials with different combinations of instructions and few-shot examples to find the optimal combination using Bayesian Optimization.
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: == Trial 1 / 10 - Full Evaluation of Default Program ==
# Average Metric: 4.41 / 6 (73.5%): 100%|██████████| 6/6 [00:00<00:00, 431.80it/s]
# 2026/01/30 19:04:32 INFO dspy.evaluate.evaluate: Average Metric: 4.409090909033575 / 6 (73.5%)
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: Default program score: 73.48
#
# /Users/felixboelter/Documents/GitHub/pilotprojekt-GrundschutzKI/.venv/lib/python3.12/site-packages/dspy/teleprompt/mipro_optimizer_v2.py:646: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   sampler = optuna.samplers.TPESampler(seed=seed, multivariate=True)
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 2 / 10 =====
# Average Metric: 4.15 / 6 (69.1%): 100%|██████████| 6/6 [00:00<00:00, 959.06it/s]
# 2026/01/30 19:04:32 INFO dspy.evaluate.evaluate: Average Metric: 4.1472222222462225 / 6 (69.1%)
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 69.12 with parameters ['Predictor 0: Instruction 1', 'Predictor 0: Few-Shot Set 3'].
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12]
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:32 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 3 / 10 =====
# Average Metric: 4.14 / 6 (69.0%): 100%|██████████| 6/6 [00:00<00:00, 2814.02it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.138189588213588 / 6 (69.0%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 68.97 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 0'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 4 / 10 =====
# Average Metric: 4.15 / 6 (69.1%): 100%|██████████| 6/6 [00:00<00:00, 2785.37it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.1472222222462225 / 6 (69.1%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 69.12 with parameters ['Predictor 0: Instruction 1', 'Predictor 0: Few-Shot Set 5'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 5 / 10 =====
# Average Metric: 4.01 / 6 (66.8%): 100%|██████████| 6/6 [00:00<00:00, 536.96it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.008147512864494 / 6 (66.8%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 66.8 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 2'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12, 66.8]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 6 / 10 =====
# Average Metric: 4.01 / 6 (66.8%): 100%|██████████| 6/6 [00:00<00:00, 348.91it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.009090909081409 / 6 (66.8%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 66.82 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 5'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12, 66.8, 66.82]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 7 / 10 =====
# Average Metric: 4.14 / 6 (69.0%): 100%|██████████| 6/6 [00:00<00:00, 875.00it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.138189588213588 / 6 (69.0%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 68.97 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 0'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12, 66.8, 66.82, 68.97]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 8 / 10 =====
# Average Metric: 4.01 / 6 (66.8%): 100%|██████████| 6/6 [00:00<00:00, 2891.63it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.008147512864494 / 6 (66.8%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 66.8 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 5'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12, 66.8, 66.82, 68.97, 66.8]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 9 / 10 =====
# Average Metric: 4.15 / 6 (69.1%): 100%|██████████| 6/6 [00:00<00:00, 3040.82it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.1472222222462225 / 6 (69.1%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 69.12 with parameters ['Predictor 0: Instruction 1', 'Predictor 0: Few-Shot Set 4'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12, 66.8, 66.82, 68.97, 66.8, 69.12]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 10 / 10 =====
# Average Metric: 4.01 / 6 (66.8%): 100%|██████████| 6/6 [00:00<00:00, 2695.57it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.008147512864494 / 6 (66.8%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 66.8 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 5'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12, 66.8, 66.82, 68.97, 66.8, 69.12, 66.8]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: =========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 11 / 10 =====
# Average Metric: 4.41 / 6 (73.5%): 100%|██████████| 6/6 [00:00<00:00, 2545.60it/s]
# 2026/01/30 19:04:33 INFO dspy.evaluate.evaluate: Average Metric: 4.409090909033575 / 6 (73.5%)
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 73.48 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 0'].
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [73.48, 69.12, 68.97, 69.12, 66.8, 66.82, 68.97, 66.8, 69.12, 66.8, 73.48]
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 73.48
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: =========================
#
#
# 2026/01/30 19:04:33 INFO dspy.teleprompt.mipro_optimizer_v2: Returning best identified program with score 73.48!

# %%
dspy_dev_answers = []
split = max(1, len(dataset) // 5)
dev_rows = list(dataset)[split:]
for i, row in enumerate(dev_rows):
    print(f"\n--- SAMPLE {i+1} ---")
    contexts = row["contexts"]
    print("QUESTION:", row["question"])
    pred = optimized_rag(question=row["question"], docs=contexts)
    dspy_dev_answers.append(pred.response)
    print("PREDICTED ANSWER:", pred.response)
    print("GROUND TRUTH:", row["ground_truth_answer"])

# Neues Dataset fürs Scoring
from datasets import Dataset

dev_dataset = Dataset.from_dict({
    "question": [r["question"] for r in dev_rows],
    "contexts": [r["contexts"] for r in dev_rows],
    "ground_truth_answer": [r["ground_truth_answer"] for r in dev_rows],
    "ground_truth_context": [r["ground_truth_context"] for r in dev_rows],
    "answer": dspy_dev_answers,   # <- DSPy Antworten
})
# Out:
# --- SAMPLE 1 ---
# QUESTION: Was ist bei der Auswahl eines externen Webhosters zu beachten?
# PREDICTED ANSWER: Bei der Auswahl eines externen Webhosters muss vertraglich geregelt werden, wie die Dienste zu erbringen sind, insbesondere Sicherheitsaspekte in einem Service‑Level‑Agreement (SLA). Der Host­er sollte die eingesetzten IT‑Systeme regelmäßig kontrollieren und warten, bei technischen Problemen oder Kompromittierungen zeitnah reagieren und grundlegende technische sowie organisatorische Maßnahmen zum Schutz des Informationsverbundes umsetzen.
# GROUND TRUTH: Bei der Nutzung externer Webhosting-Dienste sollte vertraglich geregelt werden, wie die Dienste erbracht werden. Sicherheitsaspekte müssen im Service Level Agreement (SLA) festgehalten werden. Der Webhoster sollte regelmäßig Kontrollen und Wartungen durchführen und bei technischen Problemen oder Kompromittierungen zeitnah reagieren. Er muss grundlegende technische und organisatorische Sicherheitsmaßnahmen umsetzen.
#
# --- SAMPLE 2 ---
# QUESTION: Wie sollten Fehlermeldungen auf einem Webserver gestaltet sein?
# PREDICTED ANSWER: Fehlermeldungen dürfen weder den Produktnamen noch die Versionsnummer des Webservers preisgeben und keine System‑ oder Konfigurationsdetails enthalten. Sie sollten nur allgemein darauf hinweisen, dass ein Fehler aufgetreten ist, dabei aber ein eindeutiges Merkmal (z. B. eine Fehler‑ID) zur internen Nachverfolgung enthalten. Außerdem muss sichergestellt sein, dass der Server nach einem unerwarteten Fehler nicht in einem angreifbaren Zustand verbleibt.
# GROUND TRUTH: Aus HTTP-Antworten und Fehlermeldungen dürfen weder der Produktname noch die verwendete Version des Webservers ersichtlich sein. Fehlermeldungen dürfen keine Details zu Systeminformationen oder Konfigurationen enthalten. Stattdessen sollten allgemeine Fehlermeldungen ausgegeben werden, die einen eindeutigen Hinweis für die Nachvollziehbarkeit durch den IT-Betrieb enthalten. Bei unerwarteten Fehlern darf der Webserver nicht in einem anfälligen Zustand verbleiben.
#
# --- SAMPLE 3 ---
# QUESTION: Welche Maßnahmen sind bei erhöhtem Schutzbedarf für Webserver sinnvoll?
# PREDICTED ANSWER: Bei erhöhtem Schutzbedarf sollten Webserver durch den Einsatz einer Web Application Firewall (WAF) geschützt, redundant ausgelegt und dauerhaft auf DDoS‑Angriffe überwacht werden. Zusätzlich empfiehlt sich die Nutzung restriktiver HTTP‑Header (z. B. Content‑Security‑Policy, HSTS), sicherer Cookie‑Attribute, kryptografische Absicherung vertraulicher Daten und das Vermeiden ressourcenintensiver Operationen.
# GROUND TRUTH: Bei erhöhtem Schutzbedarf sollten Webserver redundant ausgelegt werden, einschließlich redundanter Internetanbindung und ggf. weiterer Systeme wie Webanwendungsserver. Zudem sollten Maßnahmen zur Absicherung gegen DDoS-Angriffe definiert und umgesetzt werden, sowie eine ständige Überwachung des Webserver-Betriebs erfolgen.
#
# --- SAMPLE 4 ---
# QUESTION: Wer trägt die Verantwortung für Informationssicherheit beim Outsourcing?
# PREDICTED ANSWER: Die Verantwortung für die Informationssicherheit bleibt bei der auslagernden Institution, also bei den Nutzenden von Outsourcing. Die Anbietenden von Outsourcing führen die Prozesse aus, sind aber nicht für die Sicherheit verantwortlich.
# GROUND TRUTH: Die Verantwortung für Informationssicherheit verbleibt vollständig bei der auslagernden Institution.
#
# --- SAMPLE 5 ---
# QUESTION: Welche Prozesse dürfen grundsätzlich ausgelagert werden?
# PREDICTED ANSWER: Grundsätzlich können alle Prozesse ausgelagert werden, die nicht als institutionskritisch eingestuft sind und deren Kritikalität für den ordentlichen Geschäftsbetrieb gering ist. Institutionskritische Prozesse, also solche mit hoher Kritikalität oder hohem Schutzbedarf, dürfen nicht ausgelagert werden.
# GROUND TRUTH: Nur Prozesse, die risikoorientiert bewertet wurden; institutionskritische Prozesse sollen nicht unreflektiert ausgelagert werden.
#
# --- SAMPLE 6 ---
# QUESTION: Welche Mindestanforderungen gelten für Outsourcing-Verträge?
# PREDICTED ANSWER: Outsourcing‑Verträge müssen einheitliche Grundanforderungen enthalten, die zwingend Aspekte der Informationssicherheit (z. B. IT‑Grundschutz/ISMS), eine Verschwiegenheitserklärung, Service‑Level‑Agreements sowie ein Zustimmungsvorbehalt bei Weiterverlagerungen umfassen. Außerdem muss das Recht der Nutzenden auf Prüfungen, Revisionen und Audits sowie ein vertraglich geregeltes Mandanten‑Trennungskonzept (Mandantentrennung) festgeschrieben sein.
# GROUND TRUTH: Verträge müssen u. a. Informationssicherheit, Auditrechte und Zustimmung bei Weiterverlagerungen regeln. Die Grundanforderungen MÜSSEN in Vereinbarungen und Verträgen einheitlich umgesetzt werden.
#
# --- SAMPLE 7 ---
# QUESTION: Muss ich ein Sicherheitskonzept für jedes Outsourcing-Vorhaben erstellen?
# PREDICTED ANSWER: Ja. Nach den Vorgaben müssen die Nutzenden von Outsourcing für jedes einzelne Outsourcing‑Vorhaben ein eigenes Sicherheitskonzept erstellen, das auf den jeweiligen Sicherheitsanforderungen basiert. Auch die Anbieter müssen für jedes konkrete Vorhaben ein spezifisches Sicherheitskonzept vorlegen.
# GROUND TRUTH: Ja, für jedes Vorhaben ist ein Sicherheitskonzept auf Basis der relevanten IT-Grundschutz-Anforderungen zu erstellen.
#
# --- SAMPLE 8 ---
# QUESTION: Wie gehe ich mit Sub-Dienstleistern um?
# PREDICTED ANSWER: Sub‑Dienstleister sollten in ein Auslagerungsregister aufgenommen werden, das Informationen zu den Leistungen, ihrer Kritikalität und den vertraglichen Vorgaben enthält und regelmäßig geprüft wird. Sie müssen über die Sicherheitsrichtlinien des Anbieters informiert, ggf. überprüft (z. B. Führungszeugnis) und vertraglich zur Einhaltung von Qualitäts‑ und Informationssicherheitsanforderungen verpflichtet werden. Außerdem sind sie in Kommunikations‑ und Notfallkonzepte einzubeziehen, um Abhängigkeiten zu steuern.
# GROUND TRUTH: Weiterverlagerungen dürfen nur mit Zustimmung erfolgen; Anforderungen gelten auch für Sub-Dienstleister.
#
# --- SAMPLE 9 ---
# QUESTION: Welche Rolle spielt Mandantenfähigkeit?
# PREDICTED ANSWER: Mandantenfähigkeit sorgt dafür, dass Daten und Verarbeitungskontexte verschiedener Nutzer bzw. Kunden sicher voneinander getrennt sind. Sie verhindert unberechtigte Zugriffe, schützt die Vertraulichkeit und beugt rechtlichen sowie reputationsbezogenen Schäden vor.
# GROUND TRUTH: Die sichere Trennung von Daten und Verarbeitungskontexten muss vertraglich vereinbart werden.
#
# --- SAMPLE 10 ---
# QUESTION: Was ist bei der Beendigung eines Outsourcing-Verhältnisses zu regeln?
# PREDICTED ANSWER: Bei der Beendigung eines Outsourcing‑Verhältnisses müssen Regelungen festgelegt werden, wie alle Informationen, Daten und Hardware des Nutzers vom Anbieter zurückgegeben werden. Dabei sind die gesetzlichen Vorgaben zur Datenaufbewahrung zu beachten, anschließend müssen die verbleibenden Daten sicher gelöscht und dies dokumentiert werden. Zusätzlich ist zu prüfen, dass Zugangs‑ und Zugriffsrechte nach Vertragsende aufgehoben wurden.
# GROUND TRUTH: Rückgabe/Löschung von Daten, Aufhebung von Zugriffsrechten und Beachtung gesetzlicher Aufbewahrungspflichten.
#
# --- SAMPLE 11 ---
# QUESTION: Muss es eine zentrale Stelle für Outsourcing geben?
# PREDICTED ANSWER: Ja. Es muss eine zuständige Person für das Auslagerungs‑ bzw. Outsourcing‑Management etabliert werden, die als zentrale Anlaufstelle fungiert, ein zentrales Auslagerungsregister führt und regelmäßig Berichte an die Institutionsleitung liefert. Diese zentrale Stelle stellt sicher, dass Vorgänge einheitlich dokumentiert und gesteuert werden.
# GROUND TRUTH: Für Standard-Absicherung sollte eine zuständige Person für das Auslagerungsmanagement benannt werden.
#
# --- SAMPLE 12 ---
# QUESTION: Wie wird die laufende Kontrolle von Dienstleistern sichergestellt?
# PREDICTED ANSWER: Die Institution prüft Vereinbarungen und Sicherheitsanforderungen in regelmäßigen, anlassbezogenen Intervallen und nutzt dafür definierte Leistungskennzahlen (KPIs) sowie ein stets aktualisiertes Auslagerungs‑Register. Zusätzlich werden sichere Kommunikationskanäle eingerichtet und die benannten Kommunikationspartner sowie die Einhaltung von Vorgaben durch Audits kontinuierlich kontrolliert.[[ ## completed ## ]]
# GROUND TRUTH: Durch KPIs, Auslagerungsregister, regelmäßige Berichte und Audits.
#
# --- SAMPLE 13 ---
# QUESTION: Wie ist Outsourcing im Notfallmanagement zu berücksichtigen?
# PREDICTED ANSWER: Outsourcing ist im Notfallkonzept zu integrieren, indem die Abhängigkeiten ausgelagerter Prozesse berücksichtigt, Schnittstellen zu den Anbietern benannt und Verantwortliche dafür eingesetzt werden. Es sind gemeinsame Not‑ und Krisenfallpläne sowie regelmäßige Notfall‑ und Krisenübungen mit den Outsourcing‑Partnern zu etablieren, Vertrags­anforderungen (z. B. ESCROW) und ein Auslagerungsregister zu pflegen und die Vereinbarungen periodisch zu überprüfen.
# GROUND TRUTH: Anbietende sind in Notfallkonzepte einzubinden und gemeinsame Pläne abzustimmen. Es sollte gemeinsame Not- und Krisenfallpläne geben und entsprechende Übungen durchgeführt werden.
#
# --- SAMPLE 14 ---
# QUESTION: Welche Risiken entstehen durch eine unzureichende Outsourcing-Strategie?
# PREDICTED ANSWER: Durch eine unzureichende Outsourcing‑Strategie wird die Informationssicherheit vernachlässigt, was zu Schwachstellen, IT‑basierten Angriffen, Datenverlusten und unbefugtem Datenzugriff führen kann. Außerdem entstehen fehlende Transparenz und Kontrollverlust, was rechtliche, finanzielle und Reputationsschäden sowie eine gefährliche Abhängigkeit vom Anbieter zur Folge hat.
# GROUND TRUTH: Eine fehlende oder unzureichende Strategie kann dazu führen, dass Informationssicherheit im gesamten Outsourcing-Lebenszyklus nicht angemessen berücksichtigt wird. Dadurch können Prozesse beeinträchtigt werden,ausfallen oder Informationen an unbefugte Dritte abfließen.
#
# --- SAMPLE 15 ---
# QUESTION: Warum ist Abhängigkeit von Outsourcing-Anbietenden kritisch?
# PREDICTED ANSWER: Die Abhängigkeit von Outsourcing‑Anbietern kann zu Wissenverlust und eingeschränkter Kontrolle über ausgelagerte Prozesse führen, sodass die Institution Sicherheits‑ und Qualitätsmaßnahmen nicht mehr angemessen überwachen kann. Dadurch entsteht das Risiko, dass Anbieter die Situation ausnutzen, etwa durch Preissteigerungen oder Qualitätsverschlechterungen, und dass unzureichende Sicherheitsmaßnahmen implementiert werden.
# GROUND TRUTH: Abhängigkeiten können zu Wissensverlust, Kontrollverlust und falscher Einschätzung des Schutzbedarfs führen, mit Risiken für Sicherheit und Wirtschaftlichkeit.
#
# --- SAMPLE 16 ---
# QUESTION: Welche Risiken entstehen durch unzulängliche vertragliche Regelungen beim Outsourcing?
# PREDICTED ANSWER: Unzulängliche vertragliche Regelungen beim Outsourcing schaffen Sicherheitslücken im gesamten Outsourcing‑Lebenszyklus, weil Aufgaben, Leistungsparameter und Verantwortlichkeiten unklar oder missverständlich definiert sind. Dadurch können regulatorische Pflichten verletzt, Datenverlust und IT‑Angriffe verursacht sowie rechtliche, finanzielle und reputationsbezogene Schäden für beide Vertragsparteien entstehen.
# GROUND TRUTH: Unzulängliche Verträge können zu schwerwiegenden Sicherheitslücken führen, etwa durch unklare Leistungen, fehlende Sicherheitsanforderungen oder nicht erfüllte regulatorische Pflichten.
#
# --- SAMPLE 17 ---
# QUESTION: Welche Risiken bestehen für die Reputation einer Organisation durch einen erfolgreichen Webserver-Angriff?
# PREDICTED ANSWER: Ein erfolgreicher Webserver‑Angriff kann die Reputation einer Organisation erheblich schädigen, z. B. durch Defacement oder die Veröffentlichung falscher bzw. gesetzeswidriger Inhalte, was zu negativem öffentlichen Bild und möglichen Abmahnungen führt. Darüber hinaus führt ein Ausfall der Webseite zu Vertrauensverlust und kann Kunden zur Konkurrenz abwandern lassen.
# GROUND TRUTH: Bei einem erfolgreichen Angriff auf einen Webserver mit administrativen Rechten kann eine manipulierte Webseite ausgeliefert werden (Defacement), was die Reputation der Institution schädigt. Auch die Veröffentlichung falscher Informationen oder die Bereitstellung rechtswidriger Inhalte kann zu öffentlichen Schäden, Abmahnungen oder Kundenverlust führen, insbesondere wenn die Webseite nicht verfügbar ist.
#
# --- SAMPLE 18 ---
# QUESTION: Wie kann ein Angriff auf einen Webserver zur Manipulation von Inhalten führen?
# PREDICTED ANSWER: Durch das Erlangen unberechtigter Zugriffe, insbesondere administrativer Rechte, kann ein Angreifer auf die Dateisysteme und Konfiguration des Webservers zugreifen. Er kann daraufhin Webdateien ändern, Schadsoftware einsetzen oder die Webseiteninhalte austauschen (Defacement), wodurch falsche oder manipulierte Inhalte ausgeliefert werden.
# GROUND TRUTH: Bei einem unbefugten Zugriff können Angreifer die Konfiguration des Webservers ändern, Schadsoftware verbreiten oder Webinhalte manipulieren. Dies kann zu einer Verfälschung von Informationen, zur Auslieferung von schädlichen Inhalten oder zur Beeinträchtigung der Integrität des Webangebots führen.
#
# --- SAMPLE 19 ---
# QUESTION: Welche Auswirkungen haben Denial-of-Service (DoS)-Angriffe auf einen Webserver?
# PREDICTED ANSWER: DoS‑Angriffe reduzieren die Verfügbarkeit eines Webservers, indem sie Ressourcen wie CPU, Speicher oder Bandbreite überlasten, sodass das Webangebot nur noch sehr langsam oder gar nicht erreichbar ist. Das führt zu Störungen geschäftskritischer Prozesse (z. B. Online‑Shops) und kann zu Reputationsverlust und Kundenabwanderung führen.
# GROUND TRUTH: DoS- und DDoS-Angriffe können die Verfügbarkeit eines Webangebots erheblich beeinträchtigen. Durch Überlastung kann der Webserver teilweise oder vollständig außer Betrieb gehen, wodurch Clients das Angebot nicht mehr nutzen können. Für geschäftskritische Angebote wie Online-Shops kann ein solcher Ausfall schnell zu erheblichen wirtschaftlichen Schäden führen.
#
# --- SAMPLE 20 ---
# QUESTION: Wer trägt die Gesamtverantwortung für Informationssicherheit in der Institution?
# PREDICTED ANSWER: Die Institutionsleitung, also die Leitung der Institution, übernimmt die Gesamtverantwortung für die Informationssicherheit. Sie muss den Sicherheitsprozess initiieren, steuern, kontrollieren und Informationssicherheit vorleben.
# GROUND TRUTH: Die Institutionsleitung MUSS die Gesamtverantwortung für Informationssicherheit übernehmen. Sie muss den Sicherheitsprozess initiieren, steuern und kontrollieren sowie Informationssicherheit vorleben.
#
# --- SAMPLE 21 ---
# QUESTION: Was muss eine Leitlinie zur Informationssicherheit enthalten?
# PREDICTED ANSWER: Eine Leitlinie zur Informationssicherheit muss den Stellenwert der Informationssicherheit, die Sicherheitsziele sowie deren Bezug zu den Geschäftszielen und Aufgaben der Institution beschreiben. Außerdem sind die wichtigsten Aspekte der Sicherheitsstrategie, die zugehörige Organisationsstruktur und ein klar definierter Geltungsbereich anzugeben.
# GROUND TRUTH: Die Leitlinie muss den Stellenwert der Informationssicherheit, die Sicherheitsziele, die wichtigsten Aspekte der Sicherheitsstrategie sowie die Organisationsstruktur für Informationssicherheit beschreiben. Außerdem muss ein klarer Geltungsbereich festgelegt und der Bezug zu den Geschäftszielen erläutert werden.
#
# --- SAMPLE 22 ---
# QUESTION: Welche Rolle hat der oder die Informationssicherheitsbeauftragte (ISB)?
# PREDICTED ANSWER: Der oder die Informationssicherheitsbeauftragte (ISB) ist dafür verantwortlich, dass alle Anforderungen des festgelegten Sicherheitskonzepts umgesetzt und regelmäßig überprüft werden. Bei strategischen Entscheidungen muss die ISB stets einbezogen werden, um die Einhaltung der Sicherheitsmaßnahmen sicherzustellen.
# GROUND TRUTH: Der oder die ISB muss die Informationssicherheit in der Institution fördern und den Sicherheitsprozess mitsteuern und koordinieren. Er/sie muss bei allen größeren Projekten sowie bei der Einführung neuer Anwendungen und IT-Systeme frühzeitig beteiligt werden.
#
# --- SAMPLE 23 ---
# QUESTION: Welche Gefahr besteht, wenn die Institutionsleitung den Sicherheitsprozess nicht ausreichend unterstützt?
# PREDICTED ANSWER: Wird der Sicherheitsprozess von der Institutionsleitung nicht ausreichend unterstützt, lassen sich notwendige Sicherheitsmaßnahmen nur schwer durchsetzen, sodass der Prozess nicht vollständig realisierbar ist. Dies führt zu nicht umgesetzten Schutzmaßnahmen und erhöht das Risiko von Sicherheitslücken und daraus resultierenden Gefahren.
# GROUND TRUTH: Ohne uneingeschränkte Unterstützung durch die Institutionsleitung können Sicherheitsverantwortliche Schwierigkeiten haben, notwendige Maßnahmen einzufordern, insbesondere bei Personen, die in der Linienstruktur über ihnen stehen. Der Sicherheitsprozess ist dann nicht vollständig durchführbar.
#
# --- SAMPLE 24 ---
# QUESTION: Wie oft sollte das Sicherheitskonzept überprüft werden?
# PREDICTED ANSWER: Das Sicherheitskonzept sollte mindestens einmal jährlich regelmäßig überprüft werden; zusätzlich sind anlassbezogene Prüfungen (z. B. bei Änderungen oder besonderen Ereignissen) vorgesehen.
# GROUND TRUTH: Der Sicherheitsprozess, die Sicherheitskonzepte und die Organisationsstruktur sollten regelmäßig auf Wirksamkeit und Angemessenheit überprüft werden. Überprüfungen des Sicherheitsniveaus sollten mindestens jährlich sowie anlassbezogen durchgeführt werden.
#
# --- SAMPLE 25 ---
# QUESTION: Was kann passieren, wenn gegen gesetzliche Regelungen verstoßen wird?
# PREDICTED ANSWER: Verstöße gegen gesetzliche Regelungen können Bußgelder, Schadenersatz‑ oder Vertragsstrafen nach sich ziehen und im schlimmsten Fall zur Vertragsauflösung sowie zum Verlust von Geschäftsbeziehungen führen. Zudem drohen weitere rechtliche Konsequenzen und Haftungsrisiken.
# GROUND TRUTH: Wenn Informationen und IT-Systeme unzureichend abgesichert sind, kann gegen Rechtsvorschriften zur Informationsverarbeitung oder bestehende Verträge verstoßen werden. Dies kann rechtliche Konsequenzen, Vertragsstrafen, Vertragsauflösungen oder den Verlust von Geschäftsbeziehungen nach sich ziehen.
#
# --- SAMPLE 26 ---
# QUESTION: Wie müssen Mitarbeitende in den Sicherheitsprozess integriert werden?
# PREDICTED ANSWER: Alle Mitarbeitenden MÜSSEN in den Sicherheitsprozess eingebunden sein, indem sie über die für sie relevanten Gefährdungen und die geltenden Sicherheitsmaßnahmen informiert und geschult werden. Sie sollen frühzeitig in die Planung von Sicherheitsmaßnahmen einbezogen, bei Einführung von Richtlinien und Werkzeugen angeleitet und über die Konsequenzen von Regelverstößen aufgeklärt werden.
# GROUND TRUTH: Alle Mitarbeitenden müssen über Hintergründe und relevante Gefährdungen informiert sein. Sie müssen Sicherheitsmaßnahmen kennen und umsetzen, die ihren Arbeitsplatz betreffen. Sie sollten frühzeitig beteiligt werden, wenn Sicherheitsmaßnahmen zu planen sind, und müssen über Konsequenzen bei Verstößen aufgeklärt werden.
#
# --- SAMPLE 27 ---
# QUESTION: Welche Vertretungsregelungen müssen im Sicherheitsmanagement existieren?
# PREDICTED ANSWER: Im Sicherheitsmanagement müssen für alle wesentlichen Geschäfts‑ und Administrationsprozesse praktikable Vertretungsregelungen existieren. Der Aufgabenumfang, die erforderlichen Befugnisse und das notwendige Wissen der Vertretung müssen klar definiert und gesichert sein; fehlt intern die Kompetenz, müssen externe oder externe Fachkräfte benannt bzw. geschult werden. Zusätzlich sind Vertretungsregelungen für Fremd‑ und Outsourcing‑Personal einzuführen.
# GROUND TRUTH: Für alle wichtigen Funktionen der Organisation für Informationssicherheit muss es wirksame Vertretungsregelungen geben. Dies ist Teil der erforderlichen Organisationsstruktur für Informationssicherheit.
#
# --- SAMPLE 28 ---
# QUESTION: Was sollten Management-Berichte zur Informationssicherheit enthalten?
# PREDICTED ANSWER: Management‑Berichte zur Informationssicherheit müssen die aktuelle Gefährdungslage sowie die Wirksamkeit und Effizienz des Sicherheitsprozesses darstellen und dabei Probleme, Erfolge und Verbesserungspotenziale aufzeigen. Zusätzlich sind klar priorisierte Maßnahmenvorschläge mit realistischen Aufwandabschätzungen zu enthalten, und die Berichte sind revisionssicher zu archivieren.
# GROUND TRUTH: Management-Berichte sollten wesentliche Informationen über den Sicherheitsprozess enthalten, insbesondere über Probleme, Erfolge und Verbesserungsmöglichkeiten. Sie sollten klar priorisierte Maßnahmenvorschläge mit realistischen Abschätzungen zum Umsetzungsaufwand enthalten und revisionssicher archiviert werden.
#
# --- SAMPLE 29 ---
# QUESTION: Welche Risiken entstehen durch fehlende Aktualisierung im Sicherheitsprozess?
# PREDICTED ANSWER: Durch fehlende Aktualisierung werden neue Geschäftsprozesse, Anwendungen, IT‑Systeme und Bedrohungen nicht berücksichtigt, sodass das Sicherheitsniveau sinkt. Das führt zu einer schleichenden, gefährlichen Scheinsicherheit und erhöht die Anfälligkeit der Institution für Angriffe.
# GROUND TRUTH: Neue Geschäftsprozesse, Anwendungen, IT-Systeme und Bedrohungen beeinflussen permanent den Status der Informationssicherheit. Ohne effektives Revisionskonzept verringert sich das Sicherheitsniveau, und aus realer Sicherheit wird schleichend eine gefährliche Scheinsicherheit.
#
# --- SAMPLE 30 ---
# QUESTION: Wie fange ich überhaupt an? Was sind die ersten Schritte beim Aufbau eines ISMS?
# PREDICTED ANSWER: Die Institutionsleitung sollte zunächst eine übergeordnete Leitlinie zur Informationssicherheit verabschieden und einen Informationssicherheitsbeauftragten (ISB) benennen, der den Sicherheitsprozess koordiniert. Anschließend wird der Schutzbedarf der Informationsverbünde ermittelt, ein erstes Sicherheitskonzept und das IT‑Grundschutz‑Modell erstellt – das bildet die Basis für das ISMS.
# GROUND TRUTH: Der Einstieg beginnt bei der Institutionsleitung: Diese muss die Gesamtverantwortung übernehmen, Sicherheitsziele und eine Strategie festlegen sowie eine Leitlinie zur Informationssicherheit verabschieden. Parallel dazu muss eine geeignete Organisationsstruktur aufgebaut werden mit klaren Rollen und Zuständigkeiten. Erst danach folgt die Erstellung eines Sicherheitskonzepts für den definierten Informationsverbund.
#
# --- SAMPLE 31 ---
# QUESTION: Welche Ressourcen und Kompetenzen brauche ich als ISB, um meine Aufgabe erfüllen zu können?
# PREDICTED ANSWER: Als ISB benötigen Sie qualifizierte Personen, denen ausreichend personelle und finanzielle Ressourcen bereitgestellt werden, um die im Sicherheitsmanagement definierten Aufgaben und Kompetenzen zu übernehmen. Zusätzlich müssen Sie über das Fachwissen zur Umsetzung und Überprüfung des Sicherheitskonzepts, die Befugnis zur Einbeziehung in strategische Entscheidungen sowie etablierte Kommunikationswege verfügen.
# GROUND TRUTH: Die Institutionsleitung muss den ISB mit angemessenen Ressourcen ausstatten. Der ISB muss die Möglichkeit haben, bei Bedarf direkt an die Institutionsleitung zu berichten und muss bei allen größeren Projekten sowie bei der Einführung neuer Anwendungen und IT-Systeme frühzeitig beteiligt werden. Dies sichert die notwendige Einbindung in sicherheitsrelevante Entscheidungen.
#
# --- SAMPLE 32 ---
# QUESTION: Wie bringe ich die Mitarbeitenden dazu, Sicherheitsmaßnahmen auch wirklich umzusetzen?
# PREDICTED ANSWER: Binden Sie die Mitarbeitenden frühzeitig in die Planung von Sicherheitsmaßnahmen ein, informieren Sie sie verständlich über Hintergründe, relevante Gefährdungen und die für ihren Arbeitsplatz geltenden Maßnahmen und schulen Sie sie regelmäßig im sicheren Umgang. Gleichzeitig muss die Führungsebene mit gutem Beispiel vorangehen, klare Vorgaben bereitstellen und deren Einhaltung aktiv überwachen.
# GROUND TRUTH: Alle Mitarbeitenden müssen aktiv in den Sicherheitsprozess integriert werden. Sie müssen über Hintergründe und Gefährdungen informiert werden und sollten frühzeitig bei der Planung von Maßnahmen beteiligt werden. Bei der Einführung von Sicherheitsrichtlinien müssen sie ausreichend informiert werden, wie diese anzuwenden sind, und über mögliche Konsequenzen bei Verstößen aufgeklärt werden. Wichtig: Die Institutionsleitung muss Informationssicherheit vorleben.
#
# --- SAMPLE 33 ---
# QUESTION: Wie dokumentiere ich Management-Entscheidungen zu Restrisiken revisionssicher und was muss dabei beachtet werden?
# PREDICTED ANSWER: Management‑Entscheidungen zu Restrisiken müssen schriftlich festgehalten, zum Beispiel in Management‑Berichten, und eindeutig „über erforderliche Aktionen, den Umgang mit Restrisiken und Änderungen sicherheitsrelevanter Prozesse“ dokumentiert werden. Sie sind revisionssicher zu archivieren – das heißt in einem zentralen, versionierten und kontrollierten Ablagesystem zu speichern, das die aktuelle Version kurzfristig zugänglich macht und alle Vorgängerversionen unveränderlich bewahrt. Zudem sollte die Dokumentation von der Institutionsleitung unterschrieben bzw. genehmigt werden, um Nachvollziehbarkeit und Verantwortlichkeit zu sichern.
# GROUND TRUTH: Management-Berichte sollten klar priorisierte Maßnahmenvorschläge mit realistischen Abschätzungen zum Umsetzungsaufwand enthalten und revisionssicher archiviert werden. Die Management-Entscheidungen über erforderliche Aktionen, den Umgang mit Restrisiken und mit Veränderungen von sicherheitsrelevanten Prozessen müssen dokumentiert und ebenfalls revisionssicher archiviert werden. Für die Dokumentation sollte eine geregelte Vorgehensweise existieren, die Aktualität und Vertraulichkeit wahrt.
#
# --- SAMPLE 34 ---
# QUESTION: Welche Anforderungen gelten bei erhöhtem Schutzbedarf zusätzlich zum Standard-Niveau?
# PREDICTED ANSWER: Bei erhöhtem Schutzbedarf sind zusätzlich zu den Standard‑Anforderungen exemplarische Maßnahmen zu berücksichtigen, die über den Stand der Technik hinausgehen und im Rahmen einer individuellen Risikoanalyse konkretisiert werden. Beispiele sind die Einrichtung von Testumgebungen, ein verschärftes Rollen‑ und Berechtigungskonzept samt 2‑Faktor‑Authentisierung, die Nutzung einer Private Cloud, physische Netzwerk‑ und Systemtrennung sowie die Nutzung besonders abgesicherter Endgeräte oder KI‑Lösungen. Diese zusätzlichen Anforderungen sollen den Schutzbedarf gezielt erhöhen und Risiken weiter reduzieren.
# GROUND TRUTH: Bei erhöhtem Schutzbedarf sollten über den Stand der Technik hinausgehende Maßnahmen in Betracht gezogen werden. Der Baustein empfiehlt die Erstellung von zielgruppengerechten Sicherheitsrichtlinien, die bedarfsgerecht relevante Sicherheitsthemen für spezifische  Zielgruppen abbilden. Außerdem sollte geprüft werden, ob für Restrisiken Versicherungen abgeschlossen werden können, und bestehende Versicherungen sollten regelmäßig auf Aktualität überprüft werden. Die konkrete Festlegung erfolgt im Rahmen einer individuellen  Risikoanalyse.

# %%
import asyncio
from ragas.llms import llm_factory
from ragas.embeddings.litellm_provider import LiteLLMEmbeddings
from ragas.metrics.collections import ContextPrecision, ContextRecall, Faithfulness, AnswerCorrectness
import instructor
import litellm

# RAGAS LLM (LiteLLM proxy)
litellm.api_base = llm_cfg.api_base
litellm.api_key = llm_cfg.api_key
client = instructor.from_litellm(litellm.acompletion, mode=instructor.Mode.MD_JSON)
ragas_llm = llm_factory(llm_cfg.model, client=client, adapter='litellm')

embeddings = LiteLLMEmbeddings(
    model=llm_cfg.embedding_model,
    api_key=llm_cfg.api_key,
    api_base=llm_cfg.api_base,
    encoding_format='float',
)

scorers = {
    'context_precision': ContextPrecision(llm=ragas_llm),
    'context_recall': ContextRecall(llm=ragas_llm),
    'faithfulness': Faithfulness(llm=ragas_llm),
    'answer_correctness': AnswerCorrectness(llm=ragas_llm, embeddings=embeddings),
}

async def _score_row(row, sem):
    async with sem:
        return {
            'context_precision': (await scorers['context_precision'].ascore(
                user_input=row['question'],
                reference=row['ground_truth_context'],
                retrieved_contexts=row['contexts'],
            )).value,
            'context_recall': (await scorers['context_recall'].ascore(
                user_input=row['question'],
                reference=row['ground_truth_context'],
                retrieved_contexts=row['contexts'],
            )).value,
            'faithfulness': (await scorers['faithfulness'].ascore(
                user_input=row['question'],
                response=row['answer'],
                retrieved_contexts=row['contexts'],
            )).value,
            'answer_correctness': (await scorers['answer_correctness'].ascore(
                user_input=row['question'],
                response=row['answer'],
                reference=row['ground_truth_answer'],
            )).value,
        }

async def score_dataset_batched(ds, batch_size=10, concurrency=5):
    sem = asyncio.Semaphore(concurrency)
    rows = list(ds)
    results = []
    for i in range(0, len(rows), batch_size):
        batch = rows[i : i + batch_size]
        tasks = [asyncio.create_task(_score_row(r, sem)) for r in batch]
        results.extend(await asyncio.gather(*tasks))
    return results

scores = await score_dataset_batched(dev_dataset, batch_size=16, concurrency=10)
stats = {
    k: {
        'avg': sum(s[k] for s in scores) / len(scores),
        'min': min(s[k] for s in scores),
        'max': max(s[k] for s in scores),
    }
    for k in scores[0].keys()
}
print(stats)
# Out:
# {'context_precision': {'avg': 0.8942156862489662, 'min': 0.4166666666458333, 'max': 0.9999999999833333}, 'context_recall': {'avg': 0.9254901960784314, 'min': 0.3333333333333333, 'max': 1.0}, 'faithfulness': {'avg': 0.7097508700449877, 'min': 0.0, 'max': 1.0}, 'answer_correctness': {'avg': 0.6126667759628727, 'min': 0.1397254220608889, 'max': 0.991924659349372}}

# %% [markdown]
# ## Findings
#
# - TBD: Add key observations after running the notebook.
# - TBD: Summarize metrics/results (e.g., faithfulness/answer correctness).
# - TBD: Note any dataset or retrieval quality issues discovered.
